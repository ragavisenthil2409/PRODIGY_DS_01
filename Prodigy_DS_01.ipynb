# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from google.colab import files
uploaded = files.upload()

filename = list(uploaded.keys())[0]

df = pd.read_excel(filename, skiprows=3)

df.head()
# Out:
#      <input type="file" id="files-9858a56a-cf37-4c01-987a-b2cc58720a28" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9858a56a-cf37-4c01-987a-b2cc58720a28">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df.shape
# Out:
# (266, 69)

# %%
selected_countries = ['India', 'China', 'United States', 'Indonesia', 'Brazil']
df_selected = df[df['Country Name'].isin(selected_countries)]

# Extract age category columns (assuming these exist; else replace accordingly)
# Example: Suppose we assume that columns for age groups are 2022 estimates
age_data = {
    '0-14': [15.4, 17.3, 18.7, 20.1, 21.5],
    '15-64': [68.1, 70.2, 65.4, 69.3, 66.2],
    '65+': [16.5, 12.5, 15.9, 10.6, 12.3],
}
# This is mock data — replace with actual if age % columns exist

# Create DataFrame from mock age percentages
df_age = pd.DataFrame(age_data, index=selected_countries)

# Plot 1 – Age Distribution (same as before)
df_age_sum = df_age.sum()
plt.figure(figsize=(8, 5))
plt.bar(df_age_sum.index, df_age_sum.values)
plt.title("Total Age Distribution across Countries")
plt.xlabel("Age Group")
plt.ylabel("Population % Total (Mock Data)")
# Out:
# Text(0, 0.5, 'Population % Total (Mock Data)')
